# %%
import os
import pymysql
import pandas as pd
import mysql.connector
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")

# %%
conn = mysql.connector.connect(host='database-ipl-olap.c16gug4w885p.eu-north-1.rds.amazonaws.com',user=username,password=password, database='dream11')

# %%
pd.read_sql_query('SELECT * FROM batter_points', conn, index_col='index')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_21076\1620653094.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query('SELECT * FROM batter_points', conn, index_col='index')
#        match_id  batsman_name  dream11_score
# index
# 3325     501243      V Sehwag          332.0
# 2844     501210  SR Tendulkar          272.0
# 5302     598027      CH Gayle          244.0
# 2        335982   BB McCullum          216.0
# 4254     548342      V Sehwag          202.0
# ...         ...           ...            ...
# 3546     501258      ND Doshi           -8.0
# 13132   1304051      N Pooran           -8.0
# 3648     501266   S Badrinath           -8.0
# 4048     548325     DJ Jacobs           -8.0
# 10432   1175356     SR Watson           -8.0
#
# [49545 rows x 3 columns]
